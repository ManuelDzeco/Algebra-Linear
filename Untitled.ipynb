# %%
import numpy as np
import sympy as sp

# %%
A = sp.Matrix([[3,4,9],[6,3,1],[9,4,3]])
linhas, colunas = A.shape

# %%
print(linhas)
print(colunas)
# Out:
# 3
# 3

# %%
sp.pprint(a)
# Out:
# ⎡1  4/3  3⎤
# ⎢         ⎥
# ⎢6   3   1⎥
# ⎢         ⎥
# ⎣9   4   3⎦
